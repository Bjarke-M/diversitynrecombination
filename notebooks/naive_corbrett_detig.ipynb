# %%
import arviz as az
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
import xarray as xr
import random
import rpy2 
# %load_ext rpy2.ipython

# %%
df20 = pd.read_csv('../results/combined/all.csv', sep=',')

# %%
#%>% group_by(genus,species) %>% filter(!(chr=='chrX')) %>% filter(freq_mean > 0.5) %>% mutate(recomb_bin = ntile(cm_per_mb, 20))  %>% filter(!(species %in% c('zaza','albinasus')))

# %%
df20
# Out:
#           chr      start        end  freq_mean  freq_min  freq_max  \
# 0        chr1    1700001    1800000   0.395264  0.395264  0.395264
# 1        chr1    1800001    1900000   0.676817  0.676817  0.676817
# 2        chr1    1900001    2000000   0.571416  0.571416  0.571416
# 3        chr1    2100001    2200000   0.670927  0.670927  0.670927
# 4        chr1    2200001    2300000   0.727017  0.727017  0.727017
# ...       ...        ...        ...        ...       ...       ...
# 5257239  chrX  154200001  154300000   0.060007  0.059961  0.060091
# 5257240  chrX  154300001  154400000   0.668813  0.623006  0.706667
# 5257241  chrX  154400001  154500000   0.764488  0.758358  0.767728
# 5257242  chrX  154500001  154600000   0.534432  0.531385  0.536345
# 5257243  chrX  154600001  154700000   0.252523  0.232352  0.268763
#
#          freq_median  window_size_mean    sum_n_mean        species    genus  \
# 0           0.395264             99999  39526.000000    trivirgatus    Aotus
# ...
